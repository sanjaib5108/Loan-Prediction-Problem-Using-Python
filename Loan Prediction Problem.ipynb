# %% [markdown]
# # Step 1. Import Required Libraries

# %%
# import pandas library
import pandas as pd 
# import numpy for mathematical calculations
import numpy as np 
# import matplotlib for plotting graphs
import matplotlib.pyplot as plt 
# import seaborn for visualizations
import seaborn as sns 
# %matplotlib inline
# To ignore any warnings
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# # Step 2. Read Data from CSV Files

# %%
# We are to import the datasets into the environment using pd.read_csv() function.
train = pd.read_csv(r"C:\Data Files\Kaggle Datasets\Loan Prediction Problem\train.csv")
test = pd.read_csv(r"C:\Data Files\Kaggle Datasets\Loan Prediction Problem\test.csv")

# %%
# To see the top 5 rows of the Train dataset
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# To see the bottom 5 lines of the Train dataset.
train.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
# To see the information about the Train Dataset using the info() method
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
# To list all the columns of the Train Dataset using the df.columns attribute.
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
# To list the dayatypes of the Train Dataset using the df.dtypes attribute.
train.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# # Step 3. Univariate Analysis

# %%
# To find the shape of the Train Dataset using the df.shape attribute.
train.shape
print("The Number of Rows are:", train.shape[0])
print("The Number of Columns are:", train.shape[1])
# Out:
# The Number of Rows are: 614
# The Number of Columns are: 13

# %%
# To find the shape of the Test Dataset using the df.shape attribute.
test.shape
print("The Number of Rows are:", test.shape[0])
print("The Number of Columns are:", test.shape[1])
# Out:
# The Number of Rows are: 367
# The Number of Columns are: 12

# %%
# The frequency table of a variable will give us the count of each category in that variable.
# We will find the Loan Status Column as it is a categorical value in the dataset.
train['Loan_Status'].value_counts()
print("The Number of applications approved are:", train['Loan_Status'].value_counts()[0])
print("The Number of applications rejected are:", train['Loan_Status'].value_counts()[1])
# Out:
# The Number of applications approved are: 422
# The Number of applications rejected are: 192

# %%
# Let us normalize the values. Normalize can be set to True to print the proportions instead of number.
train['Loan_Status'].value_counts(normalize=True)
print("The Number of applications approved are:",train['Loan_Status'].value_counts(normalize=True)[0])
print("The Number of applications approved are:",train['Loan_Status'].value_counts(normalize=True)[1])
# Out:
# The Number of applications approved are: 0.6872964169381107
# The Number of applications approved are: 0.3127035830618892

# %%
# Let us plot the values into a Bar Plot to compare the values. 
# A Bar Plot It shows the relationship between a numeric and a categoric variable.
train['Loan_Status'].value_counts().plot.bar()
plt.xlabel("Loan Status")
plt.ylabel("Number of Applications")
plt.show()

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
# Let us now visualize the categorical and ordinal features from the dataset.
# Independent Variable (Categorical)
plt.figure(1) 
plt.subplot(221) 
train['Gender'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'Gender', color='green') 
plt.subplot(222) 
train['Married'].value_counts(normalize=True).plot.bar(title= 'Married', color='green') 
plt.subplot(223) 
train['Self_Employed'].value_counts(normalize=True).plot.bar(title= 'Self_Employed', color='green') 
plt.subplot(224) 
train['Credit_History'].value_counts(normalize=True).plot.bar(title= 'Credit_History', color='green') 
plt.show()

# %%
# Let us visualize the Independent (ordinal) variables.
# Independent Variable (Ordinal)
plt.figure(1) 
plt.subplot(131)
train['Dependents'].value_counts(normalize=True).plot.bar(figsize=(25,6),title='Dependents', color = 'purple') 
plt.subplot(132)
train['Education'].value_counts(normalize=True).plot.bar(title= 'Education', color = 'purple') 
plt.subplot(133) 
train['Property_Area'].value_counts(normalize=True).plot.bar(title= 'Property_Area', color = 'purple')
plt.show()

# %%
# Let us visualiza the Numerical values of the dataset.
# Independent Variable (Numerical)
plt.figure(1) 
plt.subplot(121) 
sns.distplot(train['ApplicantIncome']); 
plt.subplot(122) 
train['ApplicantIncome'].plot.box(figsize=(20,8)) 
plt.show()

# %%
# Let us look at the distribution of the LoanAmount variable.
plt.figure(1) 
plt.subplot(121)
df=train.dropna()
sns.distplot(train['LoanAmount']); 
plt.subplot(122)
train['LoanAmount'].plot.box(figsize=(16,5)) 
plt.show()

# %% [markdown]
# # Step 4. Bivariate Analysis

# %%
# We will find the relation between the target variable and categorical independent variables.
# Crosstab() is an important tool for analyzing two categorical variables in a dataset.
Gender=pd.crosstab(train['Gender'],train['Loan_Status']) 
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", figsize=(6,6))
plt.show()

# %%
# Now let us visualize the remaining categorical variables vs the target variables.
Married=pd.crosstab(train['Married'],train['Loan_Status']) 
Dependents=pd.crosstab(train['Dependents'],train['Loan_Status']) 
Education=pd.crosstab(train['Education'],train['Loan_Status']) 
Self_Employed=pd.crosstab(train['Self_Employed'],train['Loan_Status']) 
Married.div(Married.sum(1).astype(float), axis=0).plot(kind="bar", figsize=(6,4)) 
plt.show() 
Dependents.div(Dependents.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
plt.show() 
Education.div(Education.sum(1).astype(float), axis=0).plot(kind="bar", figsize=(6,4)) 
plt.show() 
Self_Employed.div(Self_Employed.sum(1).astype(float),axis=0).plot(kind="bar",figsize=(6,4))
plt.show()

# %%
# Now we will look at the relationship between the remaining categorical independent variables and Loan_Status.
Credit_History=pd.crosstab(train['Credit_History'],train['Loan_Status']) 
Property_Area=pd.crosstab(train['Property_Area'],train['Loan_Status']) 
Credit_History.div(Credit_History.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(6,4)) 
plt.show() 
Property_Area.div(Property_Area.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True) 
plt.show()

# %%
# Now let’s visualize numerical independent variables with respect to the target variable.
# Numerical Independent Variable vs Target Variable.
train.groupby('Loan_Status')['ApplicantIncome'].mean().plot.bar(color = 'brown')
plt.ylabel("Applicant Income")
plt.xlabel("Loan Status")
plt.show()

# %%
# Let us make bins for the applicant income variable based on the values in it and analyze the corresponding loan status for each bin.
bins=[0,2500,4000,6000,81000] 
group=['Low Income','Average Income','High Income', 'Very High Income'] 
train['Income_bin']=pd.cut(train['ApplicantIncome'],bins,labels=group) # Use pd.cut() when you need to segment and sort data values into bins.
Income_bin=pd.crosstab(train['Income_bin'],train['Loan_Status']) 
Income_bin.div(Income_bin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(10,8)) 
plt.xlabel('Applicant Income') 
P = plt.ylabel('Percentage')

# %%
# We will analyze the applicant’s income and loan amount variable in a similar manner.
bins=[0,1000,3000,42000] 
group=['Low Income','Average Income','High Income'] 
train['Coapplicant_Income_bin']=pd.cut(train['CoapplicantIncome'],bins,labels=group) # Use pd.cut() when you need to segment and sort data values into bins.
Coapplicant_Income_bin=pd.crosstab(train['Coapplicant_Income_bin'],train['Loan_Status']) 
Coapplicant_Income_bin.div(Coapplicant_Income_bin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(10,8)) 
plt.xlabel('Co-Applicant Income') 
plt.ylabel('Percentage')
plt.show()

# %%
# Let us combine the Applicant Income and Co-applicant Income and see the combined effect of Total Income on the Loan_Status.
# As per the above bar chart, the Co-Applicant income has played a role in the chances of loan being accepted.
train['Total_Income']=train['ApplicantIncome']+train['CoapplicantIncome']
bins=[0,2500,4000,6000,81000] 
group=['Low Income','Average Income','High Income', 'Very High Income'] 
train['Total_Income_bin']=pd.cut(train['Total_Income'],bins,labels=group) # Use pd.cut() when you need to segment and sort data values into bins.
Total_Income_bin=pd.crosstab(train['Total_Income_bin'],train['Loan_Status']) 
Total_Income_bin.div(Total_Income_bin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(10,8)) 
plt.xlabel('Total Income of The Applicant') # Total Income is combination of Applicant and Co-Applicant's income.
P = plt.ylabel('Percentage')

# %%
# Let’s visualize the Loan amount variable.
bins=[0,100,200,700] 
group=['Low Income','Average Income','High Income'] 
train['LoanAmount_bin']=pd.cut(train['LoanAmount'],bins,labels=group) # Use pd.cut() when you need to segment and sort data values into bins.
LoanAmount_bin=pd.crosstab(train['LoanAmount_bin'],train['Loan_Status']) 
LoanAmount_bin.div(LoanAmount_bin.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(10,8)) 
plt.xlabel('Loan Amount') 
P = plt.ylabel('Percentage')

# %%
train=train.drop(['Income_bin', 'Coapplicant_Income_bin',
 'LoanAmount_bin', 'Total_Income_bin', 'Total_Income'], axis=1)
train['Dependents'].replace('3+', 3,inplace=True) 
test['Dependents'].replace('3+', 3,inplace=True) 
train['Loan_Status'].replace('N', 0,inplace=True) 
train['Loan_Status'].replace('Y', 1,inplace=True)

# %%
matrix = train.corr(numeric_only = True) 
f, ax = plt.subplots(figsize=(9, 6)) 
sns.heatmap(matrix, vmax=.8, square=True, cmap="BuPu");

# %% [markdown]
# # Step 4. Missing Value and Outlier Treatment

# %%
# Missing values must be treated before acting on the data.
# Missing values can be deleted or imputed by following certain methods.
# Let us now list out the feature-wise count of missing values.
train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train.isnull().sum().sum()
print("The total missing values in the dataset are:", train.isnull().sum().sum())
# Out:
# The total missing values in the dataset are: 149

# %%
# The imputation of the missing values is important for the accurate results of the Data Analysis. 
# We will follow the below methods to do this.
# For numerical variables: imputation using mean or median.
# For categorical variables: imputation using mode.
train['Gender'].fillna(train['Gender'].mode()[0], inplace=True)
train['Married'].fillna(train['Married'].mode()[0], inplace=True)
train['Dependents'].fillna(train['Dependents'].mode()[0], inplace=True)
train['Self_Employed'].fillna(train['Self_Employed'].mode()[0], inplace=True)
train['Credit_History'].fillna(train['Credit_History'].mode()[0], inplace=True)

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
# Let us look at the value count of the Loan amount term variable.
# The value 360 is repeated most of the times.
train['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
train['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].mode()[0], inplace=True)

# %%
train['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    526
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
train['LoanAmount'].fillna(train['LoanAmount'].median(), inplace=True)

# %%
# All the missing values have been filled in the test dataset as we have imputed the missing values.
train.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# Now let us see the missing values in the test dataset.
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
# Let’s fill all the missing values in the test dataset too with the same approach.
# For numerical variables: imputation using mean or median.
# For categorical variables: imputation using mode.
test['Gender'].fillna(train['Gender'].mode()[0], inplace=True) 
test['Dependents'].fillna(train['Dependents'].mode()[0], inplace=True) 
test['Self_Employed'].fillna(train['Self_Employed'].mode()[0], inplace=True) 
test['Credit_History'].fillna(train['Credit_History'].mode()[0], inplace=True) 
test['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].mode()[0], inplace=True) 
test['LoanAmount'].fillna(train['LoanAmount'].median(), inplace=True)

# %%
# Now let us see the missing values in the test dataset.
# After imputing the missing values, the test dataset has no missing values.
test.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
# Let us deal with the outliers. Outliers can distort statistical analyses, affecting mean, variance, and other measures. 
# Removal of outliers will improve model performance and data accuracy.
# Let’s visualize the effect of log transformation. We will do similar changes to the test data simultaneously.
train['LoanAmount_log'] = np.log(train['LoanAmount']) 
train['LoanAmount_log'].hist(bins=20) 
test['LoanAmount_log'] = np.log(test['LoanAmount'])

# %% [markdown]
# # Step 5. Model Building using Logistic Regression

# %% [markdown]
# ### Logistic Regression is used for predicting binary outcomes. We have to work on the variables in the dataset that has no impact on the analysis.

# %%
# In our datasets, Loan_ID has no impact on our analysis, hence we will drop the column from the dataset for further analysis.
train=train.drop('Loan_ID',axis=1) 
test=test.drop('Loan_ID',axis=1)

# %%
train.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'LoanAmount_log'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area',
#        'LoanAmount_log'],
#       dtype='object')

# %%
X = train.drop('Loan_Status', axis = 1) 
y = train.Loan_Status

# %%
X=pd.get_dummies(X) 
train=pd.get_dummies(train) 
test=pd.get_dummies(test)

# %%
# We will use the train_test_split function from sklearn to divide our train dataset. 
# So first, let us import train_test_split.
from sklearn.model_selection import train_test_split
x_train, x_cv, y_train, y_cv = train_test_split(X,y, test_size =0.3)

# %%
# The dataset has been divided into training and validation parts. 
# Let us import LogisticRegression and accuracy_score from sklearn and fit the logistic regression model.
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression() 
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_cv = model.predict(x_cv)

# %%
accuracy_score(y_cv,pred_cv)
# Out:
# 0.8

# %%
# Let’s make predictions for the test dataset.
pred_test = model.predict(test)

# %%
# Let’s import the submission file which we have to submit on the solution checker.
submission=pd.read_csv(r"C:\Data Files\Kaggle Datasets\Loan Prediction Problem\Sample_Submission_ZAuTl8O_FK3zQHh.csv")

# %%
test
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History  LoanAmount_log  Gender_Female  Gender_Male  Married_No  \
# ...

# %%
submission['Loan_Status'].replace(0, 'N',inplace=True) 
submission['Loan_Status'].replace(1, 'Y',inplace=True)

# %%
pd.DataFrame(submission, columns=['Loan_ID','Loan_Status']).to_csv('logistic.csv')

# %% [markdown]
# # Step 6. Logistic Regression Using Stratified k-folds Cross-validation

# %%
# Import StratifiedKFold from sklearn.
from sklearn.model_selection import StratifiedKFold

# %%
# Let us make a cross-validation logistic model with stratified 5 folds and make predictions for the test dataset.

i=1
kf = StratifiedKFold(n_splits=5,random_state=1,shuffle=True) 
for train_index,test_index in kf.split(X,y):
     print("{} of kfold {}".format(i,kf.n_splits))
     xtr,xvl = X.iloc[train_index],X.iloc[test_index]
     ytr,yvl = y.iloc[train_index],y.iloc[test_index]
     model = LogisticRegression(random_state=1)
     model.fit(xtr, ytr)
     pred_test = model.predict(xvl)
     score = accuracy_score(yvl,pred_test)
     print("accuracy_score",score)
     i+=1

pred_test = model.predict(test)
pred=model.predict_proba(xvl)[:,1]
# Out:
# 1 of kfold 5
# accuracy_score 0.8048780487804879
# 2 of kfold 5
# accuracy_score 0.8373983739837398
# 3 of kfold 5
# accuracy_score 0.7804878048780488
# 4 of kfold 5
# accuracy_score 0.7886178861788617
# 5 of kfold 5
# accuracy_score 0.7950819672131147

# %%
# The mean validation accuracy for this model turns out to be 0.81.
# Let us visualize the roc curve.
from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(yvl,  pred)
auc = metrics.roc_auc_score(yvl, pred) 
plt.figure(figsize=(12,8)) 
plt.plot(fpr,tpr,label="validation, auc="+str(auc), color = 'green')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate') 
plt.legend(loc=4) 
plt.show()

# %%
submission['Loan_Status'].replace(0, 'N',inplace=True) 
submission['Loan_Status'].replace(1, 'Y',inplace=True)

# %%
# Let’s convert the submission to .csv format and make a submission to check the accuracy on the leaderboard.
pd.DataFrame(submission, columns=['Loan_ID','Loan_Status']).to_csv('Logistic.csv')

# %% [markdown]
# # Step 7. Feature Engineering

# %%
# Let us add a new column TotalIncome in the Train and Test datasets.
# Let us compute the Total Income of the applicants by adding Applicant Income and Co-Applicant Income together.
train['Total_Income']=train['ApplicantIncome']+train['CoapplicantIncome']
test['Total_Income']=test['ApplicantIncome']+test['CoapplicantIncome']

# %%
# Let’s check the distribution of Total Income.
sns.distplot(train['Total_Income'])
plt.show()

# %%
# We can see it is shifted towards the left, i.e., the distribution is right-skewed. 
# Let us take the log transformation to make the distribution normal.
train['Total_Income_log'] = np.log(train['Total_Income']) 
sns.distplot(train['Total_Income_log']); 
test['Total_Income_log'] = np.log(test['Total_Income'])

# %%
# Let us create the EMI feature now. EMI Column has been created by dividing the Loan Amount by Loan Amount Term.
train['EMI']=train['LoanAmount']/train['Loan_Amount_Term'] 
test['EMI']=test['LoanAmount']/test['Loan_Amount_Term']

# %%
# Let us check the distribution of the EMI variable through a dist plot.
sns.distplot(train['EMI'])
plt.show()

# %%
# Let us now create the Balance Income feature.
# Balance Income has been created by subtracting the EMI column from the Total Income and multiplying the result
# with 1000 to make the units equal.
train['Balance Income']=train['Total_Income']-(train['EMI']*1000) 
# Multiply with 1000 to make the units equal 
test['Balance Income']=test['Total_Income']-(test['EMI']*1000)

# %%
# Let us visualize the feature Balance Income through a dist plot.
sns.distplot(train['Balance Income'])
plt.show()

# %%
# Let us now drop the variables which we used to create these new features.
train=train.drop(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
 'Loan_Amount_Term'], axis=1)
test=test.drop(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
 'Loan_Amount_Term'], axis=1)

# %% [markdown]
# # Step 8. Model Building

# %%
# Let us prepare the data for feeding into the models.
X = train.drop('Loan_Status',axis =1) 
y = train.Loan_Status

# %% [markdown]
# ## Decision Tree.

# %% [markdown]
# ### A decision tree is a type of supervised learning algorithm that is mostly used in classification problems.

# %%
# Import tree from sklearn.
from sklearn import tree

# %%
# Let us fit the decision tree model with 5 folds of cross-validation.

i=1 
kf = StratifiedKFold(n_splits=5,random_state=1,shuffle=True) 
for train_index,test_index in kf.split(X,y): 
    print('{} of kfold {}'.format(i,kf.n_splits)) 
    xtr,xvl = X.loc[train_index],X.loc[test_index] 
    ytr,yvl = y[train_index],y[test_index] 
    model = tree.DecisionTreeClassifier(random_state=1) 
    model.fit(xtr, ytr) 
    pred_test = model.predict(xvl) 
    score = accuracy_score(yvl,pred_test) 
    print('accuracy_score',score) 
    i+=1 
pred_test = model.predict(test)
# Out:
# 1 of kfold 5
# accuracy_score 0.7398373983739838
# 2 of kfold 5
# accuracy_score 0.6991869918699187
# 3 of kfold 5
# accuracy_score 0.7560975609756098
# 4 of kfold 5
# accuracy_score 0.7073170731707317
# 5 of kfold 5
# accuracy_score 0.6721311475409836

# %%
submission['Loan_Status'].replace(0, 'N',inplace=True) 
submission['Loan_Status'].replace(1, 'Y',inplace=True)

# %%
# Converting submission file to .csv format 
pd.DataFrame(submission, columns=['Loan_ID','Loan_Status']).to_csv('Decision Tree.csv')

# %% [markdown]
# ## Random Forest

# %%
# let us import RandomForestClassifier from sklearn
from sklearn.ensemble import RandomForestClassifier

# %%
# Let us fit the Random Forest model with 5 folds of cross-validation.
i=1 
kf = StratifiedKFold(n_splits=5,random_state=1,shuffle=True) 
for train_index,test_index in kf.split(X,y): 
    print('{} of kfold {}'.format(i,kf.n_splits)) 
    xtr,xvl = X.loc[train_index],X.loc[test_index] 
    ytr,yvl = y[train_index],y[test_index] 
    model = RandomForestClassifier(random_state=1, max_depth=10)     
    model.fit(xtr, ytr) 
    pred_test = model.predict(xvl) 
    score = accuracy_score(yvl,pred_test) 
    print('accuracy_score',score) 
    i+=1 
pred_test = model.predict(test)
# Out:
# 1 of kfold 5
# accuracy_score 0.8292682926829268
# 2 of kfold 5
# accuracy_score 0.8130081300813008
# 3 of kfold 5
# accuracy_score 0.7723577235772358
# 4 of kfold 5
# accuracy_score 0.8048780487804879
# 5 of kfold 5
# accuracy_score 0.7540983606557377

# %%
submission['Loan_Status'].replace(0, 'N',inplace=True) 
submission['Loan_Status'].replace(1, 'Y',inplace=True)

# %%
# Converting submission file to .csv format 
pd.DataFrame(submission, columns=['Loan_ID','Loan_Status']).to_csv('Random  Forest.csv')

# %%
importances=pd.Series(model.feature_importances_, index=X.columns) 
importances.plot(kind='barh', figsize=(12,8), color = 'purple')
plt.show()
